# %% [markdown]
# # AI Hallucination & Factuality Evaluator

# %%
import pandas as pd
df=pd.read_csv('../data/raw/factuality_benchmark.csv')
df.head()

# %%
from src.factuality import evaluate_dataset
results=pd.DataFrame(evaluate_dataset(df))
pd.concat([df[['example_id','category']],results],axis=1)
